# %% [markdown]
# # Exercise 1
#
# In this exercise, we will practice applying a denoising encoder using the `FASHIO_MNIST` dataset.
#
# ### Exercise 1(a) (5 points)
#
# Load the below libraries and the `FASHION_MNIST` dataset.
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# import tensorflow as tf
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.models import Model
#
# from tensorflow.keras.datasets import fashion_mnist
#
# np.random.seed(11)
# tf.random.set_seed(11)
# batch_size = 256
# max_epochs = 50
# learning_rate = 1e-3
# momentum = 8e-1
# hidden_dim = 128
# original_dim = 784
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model

from tensorflow.keras.datasets import fashion_mnist

np.random.seed(11)
tf.random.set_seed(11)
batch_size = 256
max_epochs = 50
learning_rate = 1e-3
momentum = 8e-1
hidden_dim = 128
original_dim = 784

# %% [markdown]
# ### Exercise 1(b) (5 points)
#
# Load the `MNIST` data, and visualize the first 10 images from the `train` and `test` data sets.

# %%
(x_train, _), (x_test, _) = fashion_mnist.load_data()

n = 10 
plt.figure(figsize=(20, 8))
for i in range(n):
    plt.subplot(1, n, i+1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    
    plt.subplot(2, n, i+1+n)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.axis('off')

# %% [markdown]
# ### Exercise 1(c) (3 points)
#
# Normalize the data by dividing by 255. Then, reshape the data.

# %%
x_train = x_train / 255
x_test = x_test / 255

x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

#reshaping the input data
x_train = x_train.reshape((x_train.shape[0], original_dim))
x_test = x_test.reshape((x_test.shape[0], original_dim))

# %% [markdown]
# ### Exercise 1(d) (3 points)
#
# Add noise to the `train` and `test` data sets.

# %%
#adding noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# ### Exercise 1(e) (10 points)
#
# Define the denoising encoder model.

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, hidden_dim):
        super(Encoder, self).__init__()
        self.hidden_layer = Dense(units=hidden_dim, activation="relu")

    def call(self, input_features):
        activation = self.hidden_layer(input_features)
        return activation

class Decoder(tf.keras.layers.Layer):
    def __init__(self, hidden_dim, original_dim):
        super(Decoder, self).__init__()
        self.output_layer = Dense(units=original_dim, activation="relu")

    def call(self, encoded):
        activation = self.output_layer(encoded)
        return activation 

class Autoencoder(Model):
    def __init__(self, hidden_dim, original_dim):
        super(Autoencoder, self).__init__()
        self.loss = []
        self.encoder = Encoder(hidden_dim=hidden_dim)
        self.decoder = Decoder(hidden_dim=hidden_dim, original_dim=original_dim)

    def call(self, input_features):
        encoded = self.encoder(input_features)
        reconstructed = self.decoder(encoded)
        return reconstructed

# %% [markdown]
# ### Exercise 1(f) (6 points)
#
# Train the autoencoder using the `train` and noisy `train`, and validate it with the `test` and noisy `test`. Visualize the loss.

# %%
# create an instance of the model
model = Autoencoder(hidden_dim=hidden_dim, original_dim=original_dim)

# compile the model
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate))

#trian the model
loss = model.fit(x_train_noisy, x_train, validation_data=(x_test_noisy, x_test), epochs=max_epochs, batch_size=batch_size)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0687 - val_loss: 0.0280
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0265 - val_loss: 0.0235
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0227 - val_loss: 0.0217
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0212 - val_loss: 0.0208
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0197 - val_loss: 0.0198
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0193 - val_loss: 0.0195
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0184 - val_loss: 0.0188
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0181 - val_loss: 0.0185
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0181 - val_loss: 0.0185
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0180 - val_loss: 0.0185
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0180 - val_loss: 0.0184
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0180 - val_loss: 0.0184
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0179 - val_loss: 0.0183
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0179 - val_loss: 0.0183
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0177 - val_loss: 0.0182
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0177 - val_loss: 0.0182
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0177 - val_loss: 0.0182
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0177 - val_loss: 0.0181
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0181
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0181
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0180
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0180
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0180

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(max_epochs), loss.history['loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show();

# %% [markdown]
# ### Exercise 1(g) (6 points)
#
# Visualize the first 10 images from the noisy `test` data, and their corresponding denoised images.

# %%
n = 10 
plt.figure(figsize=(20, 8))
for i in range(n):
    plt.subplot(1, n, i+1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    
    plt.subplot(2, n, i+1+n)
    plt.imshow(model(x_test_noisy)[i].numpy().reshape(28, 28), cmap='gray')
    plt.axis('off')
